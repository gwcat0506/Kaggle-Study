# %%
import pandas as pd

data = pd.read_csv("data/house-prices-advanced-regression-techniques/train.csv")
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# 81개의 컬럼과 1460개의 데이터
data.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### 컬럼확인

# %%
# SalePrice - 부동산의 판매 가격(달러)입니다. 이것은 예측하려는 대상 변수입니다.
# MSSubClass : 건물 클래스
# MSZoning : 일반적인 구역 분류
# LotFrontage : 건물에 연결된 거리의 선형 피트
# LotArea : 부지 크기(제곱피트)
# Street : 도로 접근 유형
# Alley : 골목 진입 방식
# LotShape : 속성의 일반적인 모양
# LandContour : 속성의 평탄도
# 유틸리티 : 사용 가능한 유틸리티 유형
# LotConfig : 로트 구성
# LandSlope : 속성의 기울기
# 인근 지역 : Ames 시 경계 내의 물리적 위치
# 조건 1 : 간선도로 또는 철도와 인접
# 조건 2 : 주요 도로 또는 철도와의 근접성(두 번째가 있는 경우)
# BldgType : 주거형태
# HouseStyle : 주거 형태
# OverallQual : 전반적인 재료 및 마감 품질
# OverallCond : 전반적인 상태 등급
# YearBuilt : 원래 건설 날짜
# YearRemodAdd : 리모델링 날짜
# RoofStyle : 지붕의 종류
# RoofMatl : 지붕재
# Exterior1st : 주택 외부 피복재
# Exterior2nd : 주택 외부 피복재(재료가 둘 이상인 경우)
# MasVnrType : 석조 베니어 유형
# MasVnrArea : 벽돌 베니어 영역(제곱피트)
# ExterQual : 외장재 품질
# ExterCond : 외부 자재의 현재 상태
# 기초 : 기초의 종류
# BsmtQual : 지하실의 높이
# BsmtCond : 지하실의 일반적인 상태
# BsmtExposure : 파업 또는 정원 수준 지하실 벽
# BsmtFinType1 : 지하 마감면의 품질
# BsmtFinSF1 : 유형 1 마감 평방 피트
# BsmtFinType2 : 두 번째 완성된 영역의 품질(있는 경우)
# BsmtFinSF2 : 유형 2 마감 평방 피트
# BsmtUnfSF : 지하 공간의 미완성 평방 피트
# TotalBsmtSF : 지하 면적의 총 평방 피트
# 난방 : 난방의 종류
# HeatingQC : 난방 품질 및 상태
# CentralAir : 중앙 에어컨
# 전기 : 전기시스템
# 1stFlrSF : 1층 평방 피트
# 2ndFlrSF : 2층 평방 피트
# LowQualFinSF : 저품질 마감 평방 피트(모든 층)
# GrLivArea : 지상(지상) 거실 면적 평방피트
# BsmtFullBath : 지하 전체 욕실
# BsmtHalfBath : 지하 반 욕실
# FullBath : 지상 위의 전체 욕실
# HalfBath : 지상 반욕
# 침실 : 지하층 위의 침실 수
# 주방 : 주방 개수
# KitchenQual : 주방 품질
# TotRmsAbvGrd : 지상 위의 총 객실 수(욕실 제외)
# 기능 : 홈 기능 등급
# 벽난로 : 벽난로 수
# FireplaceQu : 벽난로 품질
# GarageType : 차고 위치
# GarageYrBlt : 차고가 건설된 연도
# GarageFinish : 차고 내부 마감
# GarageCars : 차량 수용 가능 차고의 크기
# GarageArea : 평방 피트 단위의 차고 크기
# GarageQual : 차고 품질
# GarageCond : 차고 조건
# PavedDrive : 포장된 진입로
# WoodDeckSF : 목재 데크 면적(제곱피트)
# OpenPorchSF : 평방 피트 단위의 열린 베란다 영역
# EnclosedPorch : 평방피트 단위의 닫힌 현관 면적
# 3SsnPorch : 제곱피트의 3계절 베란다 면적
# ScreenPorch : 스크린 베란다 면적(제곱피트)
# PoolArea : 풀 면적(평방피트)
# PoolQC : 수영장 품질
# 울타리 : 울타리 품질
# MiscFeature : 다른 범주에서 다루지 않는 기타 기능
# MiscVal : 기타 기능의 $Value
# MoSold : 판매 월
# YrSold : 판매 연도
# SaleType : 판매 유형
# SaleCondition : 판매 조건

# %%
# 총 80개의 컬럼
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ### 수치형 명목형 컬럼

# %%
# 수치형 명목형의 개수 확인
numerical_feats = data.dtypes[data.dtypes != "object"].index
print("수치형 컬럼 개수: ", len(numerical_feats))

categorical_feats = data.dtypes[data.dtypes == "object"].index
print("명목형 컬럼 개수: ", len(categorical_feats))
# Out:
# 수치형 컬럼 개수:  38
# 명목형 컬럼 개수:  43

# %%
print("수치형 컬럼 이름: ", data[numerical_feats].columns)
# Out:
# 수치형 컬럼 이름:  Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
print("명목 컬럼 이름: ", data[categorical_feats].columns)
# Out:
# 명목 컬럼 이름:  Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# ### 수치형 변수 통계값 확인

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ### 수치형 변수 이상치 확인

# %%
# IQR(튜키의 방법)을 사용 - 이상치 확인하는 함수
import numpy as np
from collections import Counter

def detect_outliers(df, n, features):
    outlier_indices = []
    for col in features:
        Q1 = np.percentile(df[col], 25)
        Q3 = np.percentile(df[col], 75)
        IQR = Q3 - Q1
        
        outlier_step = 1.5 * IQR
        
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step)].index
        outlier_indices.extend(outlier_list_col)
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(k for k, v in outlier_indices.items() if v > n)
        
    return multiple_outliers

# %% [markdown]
# ![image.png](attachment:image.png)
# https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51

# %%
### 이상치 확인
# 2개 이상의 컬럼에서 outlier로 분류되는 값
Outliers_to_drop = detect_outliers(data, 2, ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold'])

data.loc[Outliers_to_drop]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 93      94         190  C (all)         60.0     7200   Pave   NaN      Reg
# 125    126         190       RM         60.0     6780   Pave   NaN      Reg
# 165    166         190       RL         62.0    10106   Pave   NaN      Reg
# 172    173         160       RL         44.0     5306   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1350  1351          90       RL         91.0    11643   Pave   NaN      Reg
# 634    635          90       RL         64.0     6979   Pave   NaN      Reg
# 910    911          90       RL         80.0    11600   Pave   NaN      Reg
# 1292  1293          70       RM         60.0     6600   Pave   NaN      Reg
# 912    913          30       RM         51.0     6120   Pave   NaN      Reg
#
# ...

# %%
# 이상치 제거
data = data.drop(Outliers_to_drop, axis = 0).reset_index(drop=True)
data.shape
# 이상치 122개 제거
# Out:
# (1338, 81)

# %% [markdown]
# ### 수치형 변수 - 왜도 Skewness 구하기
# - Skewness(비대칭도),
#     - a=0이면 정규분포, a<0 이면 오른쪽으로 치우침, a>0이면 왼쪽으로 치우침
# - Kurtosis(첨도)
#     - 얼마나 그래프가 뾰족한지, 완만할 수록 음수의 값

# %%
# PoolArea, MiscVal, LowQualFinSF 등이 많이 왜곡된 분포를 가진 것을 알 수 있었음.
# 왜도가 음수인 값이 별로 없었음 -> 오른쪽으로 치우친 그래프 많이 존재
# 첨도가 음수인 값이 별로 없었음 -> 대부분 뾰족한 그래프 
for col in numerical_feats:
    print('{:15}'.format(col), 
          '왜도: {:05.2f}'.format(data[col].skew()) , 
          '   ' ,
          '첨도: {:06.2f}'.format(data[col].kurt())  
         )
# Out:
# Id              왜도: 00.00     첨도: -01.19
# MSSubClass      왜도: 01.37     첨도: 001.49
# LotFrontage     왜도: 01.59     첨도: 013.04
# LotArea         왜도: 07.78     첨도: 123.55
# OverallQual     왜도: 00.16     첨도: -00.05
# OverallCond     왜도: 00.74     첨도: 001.23
# YearBuilt       왜도: -0.58     첨도: -00.60
# YearRemodAdd    왜도: -0.52     첨도: -01.27
# MasVnrArea      왜도: 02.69     첨도: 011.04
# BsmtFinSF1      왜도: 00.65     첨도: -00.50
# BsmtFinSF2      왜도: 04.86     첨도: 026.86
# BsmtUnfSF       왜도: 00.87     첨도: 000.29
# TotalBsmtSF     왜도: 00.29     첨도: 001.17
# 1stFlrSF        왜도: 00.66     첨도: 000.02
# 2ndFlrSF        왜도: 00.77     첨도: -00.80
# LowQualFinSF    왜도: 12.74     첨도: 170.50
# GrLivArea       왜도: 00.66     첨도: 000.54
# BsmtFullBath    왜도: 00.56     첨도: -00.96
# BsmtHalfBath    왜도: 04.91     첨도: 024.68
# FullBath        왜도: -0.05     첨도: -01.25
# HalfBath        왜도: 00.66     첨도: -01.14
# BedroomAbvGr    왜도: -0.16     첨도: 000.92
# KitchenAbvGr    왜도: 05.36     첨도: 032.14
# ...

# %% [markdown]
# ### 결측치 확인

# %%
# 결측치 확인
data.isna().sum().sort_values(ascending = False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Id                 0
# dtype: int64

# %%
### 결측치가 존재하는 컬럼에 한해서 결측치 비율 출력

for col in data.columns:
    if data[col].isnull().sum() / data[col].shape[0] != 0:
        msperc = '{:>10}\t 결측치 비율: {:.2f}%'.format(col, 100 * (data[col].isnull().sum() / data[col].shape[0]))
        print(msperc)
# Out:
# LotFrontage	 결측치 비율: 17.12%
#      Alley	 결측치 비율: 94.10%
# MasVnrType	 결측치 비율: 0.52%
# MasVnrArea	 결측치 비율: 0.52%
#   BsmtQual	 결측치 비율: 2.32%
#   BsmtCond	 결측치 비율: 2.32%
# BsmtExposure	 결측치 비율: 2.39%
# BsmtFinType1	 결측치 비율: 2.32%
# BsmtFinType2	 결측치 비율: 2.39%
# Electrical	 결측치 비율: 0.07%
# FireplaceQu	 결측치 비율: 48.28%
# GarageType	 결측치 비율: 4.86%
# GarageYrBlt	 결측치 비율: 4.86%
# GarageFinish	 결측치 비율: 4.86%
# GarageQual	 결측치 비율: 4.86%
# GarageCond	 결측치 비율: 4.86%
#     PoolQC	 결측치 비율: 99.85%
#      Fence	 결측치 비율: 80.94%
# MiscFeature	 결측치 비율: 97.16%

# %%
missing = data.isnull().sum()

# 결측치가 존재할 경우 
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar(figsize = (12,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 수치형 변수 - 변수간의 상관관계 확인
# - Correlation Heat Map

# %%
data_cor = data.corr()
data_cor
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.023298    -0.019343 -0.020261    -0.025092
# MSSubClass     0.023298    1.000000    -0.436559 -0.297088     0.074497
# LotFrontage   -0.019343   -0.436559     1.000000  0.565983     0.219484
# LotArea       -0.020261   -0.297088     0.565983  1.000000     0.134798
# OverallQual   -0.025092    0.074497     0.219484  0.134798     1.000000
# OverallCond    0.008336   -0.092559    -0.052162 -0.036601    -0.134320
# YearBuilt     -0.007944    0.112764     0.126645  0.043240     0.608524
# YearRemodAdd  -0.015962    0.059062     0.082199  0.038170     0.559699
# MasVnrArea    -0.049381    0.063942     0.154689  0.095748     0.399365
# BsmtFinSF1    -0.008913   -0.047603     0.135176  0.164904     0.194672
# BsmtFinSF2     0.005311   -0.053434     0.013059  0.029718    -0.069487
# BsmtUnfSF     -0.009603   -0.148923     0.129522  0.048040     0.305442
# ...

# %%
# 집가격과 상관관계 높은 순으로 정렬
data_cor['SalePrice'].sort_values(ascending=False)

# 높은 상관관계
# 전반적인 재료 및 마감 품질(OverallQual)
# 거실 면적 (GrLivArea)
# 차고의 크기 면적 (GarageCars,GarageArea)
# 지하 면적의 총 평방 피트(TotalBsmtSF)
# 1층 평방 피트(1stFlrSF)
# 원래 건설 날짜(YearBuilt)
# 화장실 개수(FullBath)
# Out:
# SalePrice        1.000000
# OverallQual      0.813443
# GrLivArea        0.742453
# GarageCars       0.666957
# GarageArea       0.654073
# TotalBsmtSF      0.634082
# 1stFlrSF         0.605533
# YearBuilt        0.593385
# FullBath         0.575392
# TotRmsAbvGrd     0.544807
# YearRemodAdd     0.544597
# GarageYrBlt      0.535028
# MasVnrArea       0.474546
# Fireplaces       0.450006
# BsmtFinSF1       0.384138
# LotFrontage      0.362403
# OpenPorchSF      0.344776
# WoodDeckSF       0.335046
# LotArea          0.323844
# 2ndFlrSF         0.308950
# HalfBath         0.289125
# BsmtFullBath     0.245590
# BsmtUnfSF        0.205628
# BedroomAbvGr     0.179907
# MoSold           0.086471
# ScreenPorch      0.078215
# 3SsnPorch        0.053093
# PoolArea        -0.000320
# MiscVal         -0.017425
# Id              -0.024571
# BsmtFinSF2      -0.032057
# BsmtHalfBath    -0.039755
# YrSold          -0.040840
# MSSubClass      -0.058747
# LowQualFinSF    -0.065451
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=1.0)

f , ax = plt.subplots(figsize = (14,12))
sns.heatmap(data_cor.corr(),square = True, linewidths = 0.1,
            cmap = 'RdYlBu_r', linecolor = "white", vmax=0.8)
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(data_cor)

# %% [markdown]
# ### 아래의 변수들만 가지고 그래프 그려보기
# - SalePrice : 집 가격
# - OverallQual : 전반적인 재료 및 마감 품질
# - TotalBsmtSF : 지하 면적의 총 평방 피트
# - GrLivArea : 거실 면적
# - GarageCars : 차고의 크기
# - FullBath : 전체 욕실 개수
# - YearBuilt : 원래 건설 날짜?
# - YearRemodAdd : 리모델링 날짜

# %%
data[['SalePrice','OverallQual','TotalBsmtSF','GrLivArea','GarageCars','FullBath','YearBuilt','YearRemodAdd']]
# Out:
#       SalePrice  OverallQual  TotalBsmtSF  GrLivArea  GarageCars  FullBath  \
# 0        208500            7          856       1710           2         2
# 1        181500            6         1262       1262           2         2
# 2        223500            7          920       1786           2         2
# 3        140000            7          756       1717           3         1
# 4        250000            8         1145       2198           3         2
# ...         ...          ...          ...        ...         ...       ...
# 1333     175000            6          953       1647           2         2
# 1334     210000            6         1542       2073           2         2
# 1335     266500            7         1152       2340           1         2
# 1336     142125            5         1078       1078           1         1
# 1337     147500            5         1256       1256           1         1
#
#       YearBuilt  YearRemodAdd
# 0          2003          2003
# ...

# %%
sns.set()
columns = ['SalePrice','OverallQual','TotalBsmtSF','GrLivArea','GarageCars','FullBath','YearBuilt','YearRemodAdd']
sns.pairplot(data[columns],size = 2 ,kind ='scatter',diag_kind='kde')
plt.show()
# Out:
# /Users/gwcat/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# SalePrice YearBuilt 갈수록 높아짐
# -> 점차 집가격이 상승하고 있다.
#
# SalePrice YearRemodAdd 최근에 급격히 상승
# -> 리모델링을 최근에 할 수록 집 값 상승

# %% [markdown]
# ### 명목형 변수 - 집값 가격과 함께 분포 살피기

# %%
li_cat_feats = list(categorical_feats)
nr_rows = 15
nr_cols = 3

fig, axs = plt.subplots(nr_rows, nr_cols, figsize=(nr_cols*4,nr_rows*3))

for r in range(0,nr_rows):
    for c in range(0,nr_cols):  
        i = r*nr_cols+c
        if i < len(li_cat_feats):
            sns.boxplot(x=li_cat_feats[i], y=data["SalePrice"], data=data, ax = axs[r][c])
    
plt.tight_layout()    
plt.show()
